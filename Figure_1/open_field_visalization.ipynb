# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#local
from include_package import Welcome_party
Welcome_party().initialize()
# Out:
# ['/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/refs', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/refs/remotes', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/logs', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/logs/refs', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/logs/refs/remotes', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/.git/objects', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/utils', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/Figure_2', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/Figure_1', '/home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/videos']
# /home/morteza/dlc_projects/Analysis/Currencodes/csm_paper
# /home/morteza/dlc_projects/Analysis/Currencodes/csm_paper/utils
# ...

# %%
from dlc_iteration import dlc_db
from fig_1_visualization_config import visual_config

vis_config=visual_config()
targs=['LID']
db=dlc_db()
db.select_treatment(targets=targs)
print(db.keys)

db.get_animal(db.keys[6], '40')

ax=vis_config.visualize_ts(db, 10, 30, 7000, 100, 'LD-3mg')
# Out:
# ['26_LID', '22_LID', '27_LID', '23_LID', '25_LID', '28_LID', '21_LID']

# %%
ax=vis_config.visualize_phis(db, 12, 60, 7000, 50, 'LD-3mg')

# %%
cut=7000
phi=db.mid_head_angs_atan()[:cut]
main_ar=db.main_ar()[:cut]
_, ax = plt.subplots(2)
ax[0].plot(phi[1500:3000])
ax[0].set_ylabel('ph_mid')


ax[1].plot(main_ar[1500:3000])
ax[1].set_ylabel('mid_ar')
# Out:
# Text(0, 0.5, 'mid_ar')

# %%
ax=vis_config.visualize_ars(db, 12, 30, 7000, 50, 'LD-3mg')

# %%
ax=vis_config.visualize_trans(db, 12, 30, 7000, 50, 'LD-3mg')

# %%
ax=vis_config.visualize_rot_speed(db, 20, 50, 7000, 50, 'LD-3mg')

# %% [markdown]
#                             previous Visualizations

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


treatment='LD-3mg'
ID_n=5
time_point=30

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('LID_series.svg')
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22776/550701387.py in <module>
#       1 evalu=['LID']
# ----> 2 dct=data_base.get_dct(evalu)
#       3
#       4
#       5 treatment='LD-3mg'
#
# NameError: name 'data_base' is not defined

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


treatment='Vehicle' #color code, Figure2
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('Veh_series.svg')
plt.draw()
# Out:
# (7200,)

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)


treatment='D2Ag' #color
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D2Ag_series.svg')
plt.draw()
# Out:
# (7200,)

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)


treatment='D1Ag' #color
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D1ag_series.svg')
plt.draw()
# Out:
# (36000,)

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)


treatment='D1Ant'
ID_n=3
time_point=50

strt=15
fini=50
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D1A_series.svg')
plt.draw()
# Out:
# (17024,)

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)


treatment='D2Ant'
ID_n=3
time_point=50

strt=15
fini=50
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D2A_series.svg')
plt.draw()
# Out:
# (17012,)

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


animal_ID=4
time_point=30
lower_cut=0
upper_cut=3000
fps=50

treatment='LD-3mg'

head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarLID.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


animal_ID=4
time_point=30
lower_cut=0
upper_cut=3000
fps=50

treatment='LD-3mg'

head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarLID.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)



animal_ID=1
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ag'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarSUM.svg', dpi=360)
plt.draw()
# Out:
# (3600,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)


animal_ID=0
time_point=70
lower_cut=500
upper_cut=2500
fps=50

treatment='D1Ag'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarSKF.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)

animal_ID=2
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D1Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD1A.svg', dpi=360)
plt.draw()
# Out:
# (17023,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)


animal_ID=2
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD2A.svg', dpi=360)
plt.draw()
# Out:
# (16930,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['LES']
dct=data_base.get_dct(evalu)


animal_ID=0
time_point=71
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD2A_les.svg', dpi=360)
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\dlc_projects\Analysis\git_repo\Figures\open_field_visalization.ipynb Cell 14 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> treatment='D2Ant'
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> #print(dct[list(dct.keys())][ID_n])
# ---> <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)
# ...

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )

plt.savefig('openLID.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)

time_point=30
animal_ID=0
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openSUM.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openSKF.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2  
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD1A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD2A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['LES']
dct=data_base.get_dct(evalu)

time_point=70
animal_ID=0
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD1A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,
