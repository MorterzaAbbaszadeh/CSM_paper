# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#local
from include_package import Welcome_party
Welcome_party().initialize()
# Out:
# ['c:\\MachineShop\\CSM_paper', 'c:\\MachineShop\\CSM_paper\\data', 'c:\\MachineShop\\CSM_paper\\Figure_1', 'c:\\MachineShop\\CSM_paper\\Figure_2', 'c:\\MachineShop\\CSM_paper\\utils']
# c:\MachineShop\CSM_paper
# c:\MachineShop\CSM_paper\data
# c:\MachineShop\CSM_paper\Figure_1
# c:\MachineShop\CSM_paper\Figure_2
# c:\MachineShop\CSM_paper\utils

# %%
from dlc_iteration import dlc_db
from fig_1_visualization_config import visual_config

vis_config=visual_config()
targs=['LID']
db=dlc_db()
db.select_treatment(targets=targs)
print(db.keys)
db.get_animal(db.keys[2], '30')

ax=vis_config.visualize_ts(db, 10, 30, 7000, 50, 'LD-3mg')
# Out:
# ['26_LID', '22_LID', '27_LID', '23_LID', '25_LID', '28_LID', '21_LID']

# %%
db.get_animal(db.keys[1], '10')
# Out:
# {'26_LID': {'traces': {'30': {'headR': array([254.11975098, 254.39131165, 256.26196289, ..., 393.47360229,
#            393.69955444, 395.57330322]),
#     'headR.1': array([336.2890625 , 335.4776001 , 334.6572876 , ..., 184.18904114,
#            185.9566803 , 187.08937073]),
#     'headL': array([234.30296326, 234.05084229, 234.42565918, ..., 391.53598022,
#            391.22518921, 390.74279785]),
#     'headL.1': array([348.62850952, 347.68731689, 345.60787964, ..., 204.81117249,
#            205.02642822, 205.27604675]),
#     'mid1': array([256.31790161, 255.51226807, 255.66941833, ..., 414.90328979,
#            414.68896484, 415.64083862]),
#     'mid1.1': array([357.60888672, 356.90249634, 357.31469727, ..., 200.35150146,
#            200.68453979, 202.35627747]),
#     'mid2': array([256.05773926, 256.83773804, 252.25831604, ..., 425.83312988,
#            426.99420166, 425.7461853 ]),
#     'mid2.1': array([385.46286011, 384.95135498, 385.72039795, ..., 226.69174194,
#            226.00170898, 227.75202942]),
#     'tail': array([266.63824463, 266.44631958, 266.31921387, ..., 388.9125061 ,
#            388.70162964, 388.84420776]),
#     'tail.1': array([330.41558838, 330.0111084 , 329.03189087, ..., 184.17294312,
#            184.38973999, 185.99043274])},
#    '10': {'headR': array([337.89205933, 337.45739746, 337.08291626, ..., 243.0340271 ,
#            237.65699768, 233.23484802]),
#     'headR.1': array([256.90652466, 256.75964355, 256.72341919, ...,  83.14435577,
#             84.70572662,  88.30728149]),
#     'headL': array([317.33624268, 316.36773682, 315.64129639, ..., 237.98027039,
#            234.08203125, 231.03788757]),
#     'headL.1': array([262.30941772, 261.90509033, 262.3760376 , ..., 102.46668243,
#            104.63196564, 107.24916077]),
#     'mid1': array([332.39871216, 331.66775513, 331.2807312 , ..., 259.59796143,
#            256.92080688, 254.17089844]),
#     'mid1.1': array([281.556427  , 281.38424683, 281.08132935, ...,  96.78670502,
#             96.49034119,  98.58570862]),
#     'mid2': array([326.00817871, 325.24316406, 325.39315796, ..., 288.66748047,
#            286.5229187 , 284.84378052]),
#     'mid2.1': array([314.29830933, 314.17376709, 313.56011963, ..., 113.74475098,
#            112.55731201, 113.05138397]),
#     'tail': array([339.45266724, 339.29907227, 339.1930542 , ..., 304.84887695,
#            304.21963501, 303.37594604]),
#     'tail.1': array([246.78591919, 247.05610657, 246.80273438, ..., 128.24609375,
#            125.83964539, 123.73395538])},
#    '60': {'headR': array([256.37341309, 256.45071411, 256.15670776, ..., 309.3951416 ,
#            307.39175415, 305.69836426]),
#     'headR.1': array([125.45747375, 125.25964355, 124.4980545 , ...,  93.24121857,
#             91.81035614,  91.21381378]),
#     'headL': array([231.71627808, 231.3686676 , 231.11064148, ..., 288.90750122,
#            287.8946228 , 287.287323  ]),
#     'headL.1': array([123.20083618, 122.53477478, 122.36588287, ..., 105.32385254,
#            103.19345856, 103.14664459]),
#     'mid1': array([236.44155884, 236.07867432, 235.55197144, ..., 313.05218506,
#            312.1164856 , 311.60656738]),
#     'mid1.1': array([149.36460876, 148.55715942, 148.59732056, ..., 113.89466095,
#            113.51207733, 113.25884247]),
#     'mid2': array([221.65475464, 222.14649963, 221.87149048, ..., 320.91662598,
#            320.08184814, 320.0612793 ]),
#     'mid2.1': array([174.47732544, 174.56030273, 174.45265198, ..., 148.51100159,
#            147.92549133, 147.83306885]),
#     'tail': array([262.34515381, 261.95645142, 259.43572998, ..., 321.29736328,
#            320.68417358, 320.23324585]),
#     'tail.1': array([125.6414566 , 125.62410736, 123.44011688, ...,  92.01493073,
#             91.67454529,  91.52935028])},
#    '50': {'headR': array([375.99679565, 378.24661255, 380.61520386, ..., 251.16799927,
#            251.24406433, 252.30563354]),
#     'headR.1': array([330.37530518, 328.53759766, 326.79421997, ..., 121.45695496,
#            120.9421463 , 120.09499359]),
#     'headL': array([387.10415649, 388.71792603, 389.90936279, ..., 243.22520447,
#            243.65913391, 244.43734741]),
#     'headL.1': array([308.90383911, 305.06115723, 303.77157593, ...,  98.38173676,
#             97.55745697,  96.41566467]),
#     'mid1': array([361.46810913, 363.30215454, 363.59738159, ..., 221.92085266,
#            221.53686523, 221.66427612]),
#     'mid1.1': array([299.29162598, 298.60592651, 297.54135132, ..., 120.77639008,
#            120.43395996, 120.14788055]),
#     'mid2': array([359.11816406, 356.1656189 , 355.35610962, ..., 194.39736938,
#            194.19883728, 194.32225037]),
#     'mid2.1': array([278.91848755, 280.6288147 , 281.57208252, ..., 121.67353058,
#            121.70867157, 121.20345306]),
#     'tail': array([398.15878296, 399.39633179, 400.26724243, ..., 259.3494873 ,
#            259.37564087, 259.96438599]),
#     'tail.1': array([306.34576416, 306.23025513, 305.85012817, ..., 129.42169189,
#            129.09916687, 129.21723938])},
#    '90': {'headR': array([299.46337891, 300.26403809, 301.04220581, ..., 432.45968628,
#            433.44891357, 434.021698  ]),
#     'headR.1': array([270.03656006, 270.23007202, 270.16958618, ..., 214.2742157 ,
#            213.63450623, 212.50563049]),
#     'headL': array([317.77429199, 317.5317688 , 317.99508667, ..., 438.43838501,
#            438.41894531, 437.94042969]),
#     'headL.1': array([257.44415283, 257.44100952, 256.98348999, ..., 195.33175659,
#            194.36541748, 192.8682251 ]),
#     'mid1': array([296.30535889, 295.53601074, 294.67556763, ..., 404.59130859,
#            404.96203613, 405.1774292 ]),
#     'mid1.1': array([242.86659241, 242.54516602, 242.60775757, ..., 194.53392029,
#            194.52865601, 194.39811707]),
#     'mid2': array([280.09005737, 279.07266235, 277.69552612, ..., 383.44787598,
#            383.06097412, 382.94143677]),
#     'mid2.1': array([216.75788879, 217.38165283, 217.88761902, ..., 178.54888916,
#            179.82661438, 180.23410034]),
#     'tail': array([317.73956299, 317.28561401, 317.04159546, ..., 433.47634888,
#            433.60574341, 433.53790283]),
#     'tail.1': array([272.15768433, 272.36520386, 272.15386963, ..., 217.09786987,
#            216.34831238, 215.3605957 ])},
#    '20': {'headR': array([211.02296448, 213.78990173, 213.60839844, ..., 328.50738525,
#            327.17034912, 325.01763916]),
#     'headR.1': array([209.8614502 , 207.64402771, 207.1061554 , ..., 310.79324341,
#            311.71795654, 313.13726807]),
#     'headL': array([209.46720886, 212.14289856, 212.58155823, ..., 347.60491943,
#            346.26873779, 344.95895386]),
#     'headL.1': array([189.53688049, 186.36177063, 184.7933197 , ..., 322.97109985,
#            324.88290405, 325.00054932]),
#     'mid1': array([184.04122925, 184.60183716, 184.73426819, ..., 353.71209717,
#            351.56399536, 350.63058472]),
#     'mid1.1': array([192.6860199 , 191.39257812, 190.45236206, ..., 299.2918396 ,
#            299.44650269, 297.20123291]),
#     'mid2': array([183.3074646 , 180.27000427, 179.29515076, ..., 381.69168091,
#            379.87036133, 380.09564209]),
#     'mid2.1': array([162.40330505, 162.9831543 , 163.39935303, ..., 294.42266846,
#            294.23995972, 293.64056396]),
#     'tail': array([214.79566956, 214.77555847, 215.08589172, ..., 320.88082886,
#            320.39590454, 318.61553955]),
#     'tail.1': array([169.30220032, 168.68534851, 168.65179443, ..., 307.13665771,
#            307.51086426, 306.60974121])},
#    '70': {'headR': array([313.31954956, 312.4229126 , 311.93881226, ..., 316.93109131,
#            313.77536011, 314.68469238]),
#     'headR.1': array([265.92471313, 264.81195068, 265.97439575, ..., 382.56240845,
#            388.11831665, 386.02722168]),
#     'headL': array([312.70599365, 311.60385132, 311.23883057, ..., 336.1932373 ,
#            339.51913452, 340.49822998]),
#     'headL.1': array([287.76300049, 287.03518677, 287.91665649, ..., 392.88150024,
#            393.27658081, 392.59075928]),
#     'mid1': array([334.11587524, 333.00823975, 332.15383911, ..., 331.66049194,
#            335.27783203, 336.54003906]),
#     'mid1.1': array([279.57937622, 279.38696289, 279.69805908, ..., 377.4871521 ,
#            379.0887146 , 378.95440674]),
#     'mid2': array([353.33062744, 352.99203491, 352.83758545, ..., 351.92910767,
#            353.88067627, 355.50054932]),
#     'mid2.1': array([303.63833618, 302.53295898, 302.6847229 , ..., 371.75231934,
#            369.706604  , 369.69549561]),
#     'tail': array([305.68264771, 306.86621094, 307.21643066, ..., 291.48916626,
#            291.94476318, 291.97631836]),
#     'tail.1': array([263.4732666 , 260.71221924, 260.27160645, ..., 408.66452026,
#            409.33740234, 409.37939453])},
#    '40': {'headR': array([345.25662231, 345.60296631, 346.08267212, ..., 218.3614502 ,
#            217.93960571, 216.89259338]),
#     'headR.1': array([311.89367676, 310.73242188, 310.49368286, ..., 236.94702148,
#            240.03259277, 242.91584778]),
#     'headL': array([368.67889404, 369.39001465, 368.46859741, ..., 223.37882996,
#            225.54501343, 225.78659058]),
#     'headL.1': array([308.52716064, 306.5710144 , 304.8682251 , ..., 258.07736206,
#            260.49176025, 261.93197632]),
#     'mid1': array([351.70587158, 351.96585083, 350.97821045, ..., 245.40180969,
#            245.09423828, 244.60211182]),
#     'mid1.1': array([284.21691895, 283.42773438, 283.27581787, ..., 244.92131042,
#            246.1360321 , 247.20301819]),
#     'mid2': array([354.11276245, 353.47344971, 353.175354  , ..., 266.47277832,
#            267.06039429, 268.01812744]),
#     'mid2.1': array([254.00778198, 253.97573853, 253.95831299, ..., 264.81362915,
#            265.01553345, 264.86764526]),
#     'tail': array([334.50094604, 335.44094849, 337.25714111, ..., 237.03924561,
#            237.43385315, 237.05796814]),
#     'tail.1': array([305.47470093, 304.82501221, 305.54721069, ..., 273.5083313 ,
#            274.0484314 , 275.19113159])},
#    '80': {'headR': array([139.43205261, 144.69430542, 148.53349304, ..., 414.00177002,
#            414.63284302, 414.09161377]),
#     'headR.1': array([239.81343079, 233.59040833, 228.94270325, ..., 241.70596313,
#            239.56640625, 239.64178467]),
#     'headL': array([155.05940247, 160.61380005, 163.37236023, ..., 411.28134155,
#            412.00726318, 412.24346924]),
#     'headL.1': array([223.86183167, 217.32687378, 209.91557312, ..., 217.1391449 ,
#            216.42016602, 215.72880554]),
#     'mid1': array([134.76329041, 137.12693787, 138.81008911, ..., 394.19094849,
#            395.07702637, 394.10742188]),
#     'mid1.1': array([203.88752747, 201.55685425, 198.35037231, ..., 227.17822266,
#            226.98770142, 226.50421143]),
#     'mid2': array([143.87728882, 145.10247803, 145.54150391, ..., 374.88449097,
#            374.16531372, 373.32476807]),
#     'mid2.1': array([177.9737854 , 175.11416626, 173.14813232, ..., 208.53686523,
#            208.54808044, 208.85771179]),
#     'tail': array([171.1622467 , 174.53619385, 176.3442688 , ..., 391.10061646,
#            390.57803345, 396.92263794]),
#     'tail.1': array([194.37132263, 192.45639038, 191.05412292, ..., 243.32194519,
#            243.65007019, 242.83601379])}},
#   'treatment': 'LID',
#   'id': '26',
#   'ar0': 80.0573278590888},
#  '22_LID': {'traces': {'90': {'headR': array([352.23925781, 352.48931885, 352.52954102, ..., 508.52529907,
#            507.60366821, 507.74182129]),
#     'headR.1': array([191.52366638, 191.24998474, 191.09594727, ..., 289.67825317,
#            288.74099731, 288.39389038]),
#     'headL': array([364.13656616, 364.25024414, 364.64306641, ..., 512.14282227,
#            510.92199707, 511.16821289]),
#     'headL.1': array([211.69351196, 211.34231567, 211.15838623, ..., 261.48504639,
#            261.15090942, 260.87789917]),
#     'mid1': array([375.29992676, 375.44036865, 375.46295166, ..., 481.88977051,
#            481.23736572, 481.47335815]),
#     'mid1.1': array([183.19459534, 183.34140015, 183.30807495, ..., 272.4369812 ,
#            272.12393188, 272.1171875 ]),
#     'mid2': array([400.41720581, 400.37863159, 399.98376465, ..., 443.58468628,
#            443.33126831, 443.00872803]),
#     'mid2.1': array([160.50080872, 160.54185486, 159.65556335, ..., 275.28070068,
#            274.80645752, 275.15112305]),
#     'tail': array([374.01556396, 374.33215332, 374.42312622, ..., 419.88186646,
#            420.02172852, 419.9921875 ]),
#     'tail.1': array([128.4407196 , 128.59393311, 128.96443176, ..., 278.38668823,
#            278.41860962, 278.61764526])},
#    '10': {'headR': array([309.19561768, 308.96221924, 309.14575195, ..., 486.08886719,
#            489.36273193, 491.96435547]),
#     'headR.1': array([ 84.50138855,  84.29998779,  83.92558289, ..., 239.32563782,
#            238.90734863, 238.2571106 ]),
#     'headL': array([299.19308472, 299.43481445, 299.06329346, ..., 509.01538086,
#            510.19805908, 513.94921875]),
#     'headL.1': array([ 60.41885376,  60.50188446,  60.35610962, ..., 225.91790771,
#            223.68675232, 221.9181366 ]),
#     'mid1': array([283.15341187, 283.35839844, 283.56488037, ..., 495.04550171,
#            494.45587158, 496.20306396]),
#     'mid1.1': array([ 76.38284302,  76.16834259,  76.39012146, ..., 200.07170105,
#            199.4284668 , 197.06080627]),
#     'mid2': array([250.16362   , 250.58486938, 250.3739624 , ..., 517.04443359,
#            516.11914062, 518.02056885]),
#     'mid2.1': array([ 79.08602905,  78.98725128,  79.04763031, ..., 178.76028442,
#            177.70227051, 174.58705139]),
#     'tail': array([233.44047546, 233.49797058, 233.29615784, ..., 529.14337158,
#            529.52069092, 530.28613281]),
#     'tail.1': array([ 80.52468872,  80.60713196,  80.61911011, ..., 191.6506958 ,
#            188.39430237, 190.51184082])},
#    '40': {'headR': array([211.00149536, 207.6696167 , 206.37538147, ..., 477.75634766,
#            475.11303711, 472.95483398]),
#     'headR.1': array([312.25115967, 311.10751343, 312.04681396, ..., 178.70384216,
#            183.37017822, 188.17153931]),
#     'headL': array([191.52949524, 189.63612366, 188.79335022, ..., 472.53662109,
#            471.89715576, 473.57937622]),
#     'headL.1': array([332.81115723, 333.35598755, 334.90023804, ..., 206.61149597,
#            212.36935425, 216.04335022]),
#     'mid1': array([212.89871216, 216.78134155, 215.37731934, ..., 499.06011963,
#            497.46411133, 497.02932739]),
#     'mid1.1': array([338.8526001 , 335.6713562 , 335.07839966, ..., 199.5675354 ,
#            201.80331421, 203.40313721]),
#     'mid2': array([193.17980957, 194.75418091, 196.09700012, ..., 506.23327637,
#            508.56576538, 510.26870728]),
#     'mid2.1': array([376.36334229, 376.16897583, 376.18273926, ..., 227.83084106,
#            228.96635437, 228.06970215]),
#     'tail': array([170.28752136, 170.99098206, 170.50674438, ..., 498.43255615,
#            502.36773682, 505.39614868]),
#     'tail.1': array([340.44210815, 340.85076904, 341.02920532, ..., 255.99835205,
#            256.67407227, 257.07165527])},
#    '20': {'headR': array([495.2102356 , 495.99572754, 497.10754395, ..., 516.91479492,
#            515.54040527, 514.84429932]),
#     'headR.1': array([172.09049988, 171.21452332, 171.10986328, ..., 154.57911682,
#            155.72644043, 156.21427917]),
#     'headL': array([498.70431519, 499.00524902, 500.0552063 , ..., 493.76556396,
#            496.27264404, 496.7701416 ]),
#     'headL.1': array([145.63430786, 145.52018738, 145.54574585, ..., 157.65917969,
#            155.40829468, 154.52366638]),
#     'mid1': array([470.36584473, 470.77600098, 470.82794189, ..., 500.36074829,
#            499.06582642, 498.1574707 ]),
#     'mid1.1': array([139.07087708, 139.64247131, 139.21459961, ..., 180.96575928,
#            180.23985291, 179.63116455]),
#     'mid2': array([483.21844482, 483.14990234, 482.64077759, ..., 459.32617188,
#            458.41665649, 458.19424438]),
#     'mid2.1': array([103.85113525, 103.42778778, 103.4078064 , ..., 196.53492737,
#            197.13320923, 197.04077148]),
#     'tail': array([516.18505859, 511.92242432, 515.67938232, ..., 447.31030273,
#            447.54666138, 447.35583496]),
#     'tail.1': array([128.20910645, 125.39122009, 130.57247925, ..., 182.16320801,
#            182.35050964, 182.72346497])},
#    '50': {'headR': array([514.10015869, 515.56750488, 519.2064209 , ..., 483.24993896,
#            487.6161499 , 492.0256958 ]),
#     'headR.1': array([242.13131714, 237.41427612, 230.96284485, ..., 218.84603882,
#            221.0604248 , 220.8807373 ]),
#     'headL': array([517.0145874 , 515.9821167 , 515.03308105, ..., 504.2131958 ,
#            507.68304443, 511.15750122]),
#     'headL.1': array([214.60890198, 208.3245697 , 202.09152222, ..., 200.53358459,
#            202.07373047, 201.12696838]),
#     'mid1': array([491.39428711, 492.28619385, 491.74667358, ..., 488.04534912,
#            489.15472412, 490.94430542]),
#     'mid1.1': array([212.33033752, 211.31933594, 210.20788574, ..., 176.32200623,
#            177.44937134, 177.89227295]),
#     'mid2': array([472.40963745, 470.9491272 , 470.30969238, ..., 513.58831787,
#            513.44995117, 513.88867188]),
#     'mid2.1': array([177.56150818, 177.12223816, 176.35165405, ..., 157.28460693,
#            156.11164856, 156.37547302]),
#     'tail': array([496.26657104, 491.85321045, 486.53643799, ..., 521.40112305,
#            522.56463623, 524.1831665 ]),
#     'tail.1': array([169.17001343, 162.97869873, 158.16290283, ..., 183.25398254,
#            182.77896118, 183.44198608])},
#    '80': {'headR': array([437.25018311, 436.15866089, 436.75637817, ..., 385.95062256,
#            385.66506958, 385.67205811]),
#     'headR.1': array([159.18762207, 155.46014404, 151.76951599, ..., 115.69623566,
#            115.7331543 , 115.70367432]),
#     'headL': array([416.30154419, 415.628479  , 414.68539429, ..., 373.89230347,
#            373.77770996, 373.45657349]),
#     'headL.1': array([162.04589844, 158.06578064, 154.03753662, ..., 136.20181274,
#            136.02288818, 136.16101074]),
#     'mid1': array([429.15222168, 427.49313354, 427.48327637, ..., 406.61697388,
#            406.29458618, 405.75973511]),
#     'mid1.1': array([183.04420471, 181.76373291, 179.07762146, ..., 131.4447937 ,
#            131.41184998, 131.35806274]),
#     'mid2': array([430.93768311, 433.20007324, 431.63070679, ..., 428.84909058,
#            428.86166382, 427.73220825]),
#     'mid2.1': array([225.99798584, 222.81040955, 221.05162048, ..., 157.83988953,
#            157.84655762, 158.44966125]),
#     'tail': array([432.46304321, 430.6373291 , 427.33346558, ..., 456.33398438,
#            456.33273315, 456.87908936]),
#     'tail.1': array([259.22796631, 256.42248535, 252.61962891, ..., 134.5735321 ,
#            134.62368774, 134.31713867])},
#    '70': {'headR': array([205.61531067, 208.04652405, 210.18487549, ..., 283.46511841,
#            286.8031311 , 288.85906982]),
#     'headR.1': array([369.80474854, 372.47576904, 374.99926758, ..., 404.10290527,
#            404.12530518, 404.85501099]),
#     'headL': array([230.0199585 , 231.89929199, 234.91770935, ..., 304.23937988,
#            307.83728027, 309.98321533]),
#     'headL.1': array([372.92382812, 372.69039917, 373.37759399, ..., 395.60992432,
#            395.64730835, 396.80264282]),
#     'mid1': array([220.21824646, 221.15376282, 221.70936584, ..., 288.77337646,
#            292.18695068, 295.1020813 ]),
#     'mid1.1': array([350.13613892, 351.33428955, 351.88101196, ..., 373.35192871,
#            372.48635864, 373.03781128]),
#     'mid2': array([240.87335205, 240.73199463, 240.25714111, ..., 298.10406494,
#            299.64511108, 301.34210205]),
#     'mid2.1': array([321.81665039, 320.86083984, 320.28076172, ..., 336.31613159,
#            336.07965088, 335.6867981 ]),
#     'tail': array([267.32168579, 267.08169556, 266.58694458, ..., 308.27841187,
#            307.98110962, 308.26898193]),
#     'tail.1': array([315.51571655, 314.82888794, 314.61468506, ..., 314.0531311 ,
#            313.73989868, 313.38299561])},
#    '30': {'headR': array([518.96643066, 518.31134033, 517.54052734, ..., 512.31848145,
#            511.07513428, 510.45819092]),
#     'headR.1': array([234.39668274, 234.99584961, 234.56692505, ..., 162.25639343,
#            163.68943787, 164.82765198]),
#     'headL': array([527.27490234, 527.34594727, 526.26159668, ..., 507.45184326,
#            506.68942261, 506.22839355]),
#     'headL.1': array([207.71525574, 208.30232239, 207.44755554, ..., 139.68701172,
#            140.30253601, 140.88327026]),
#     'mid1': array([497.05502319, 497.0536499 , 496.63256836, ..., 478.96633911,
#            477.86248779, 476.818573  ]),
#     'mid1.1': array([203.38607788, 204.02281189, 204.30036926, ..., 144.99845886,
#            144.56285095, 144.73191833]),
#     'mid2': array([498.26333618, 498.18759155, 499.1769104 , ..., 469.80474854,
#            470.61984253, 470.82662964]),
#     'mid2.1': array([175.38865662, 174.8142395 , 176.08024597, ..., 114.09085083,
#            113.70678711, 113.13976288]),
#     'tail': array([528.88830566, 529.0435791 , 528.5065918 , ..., 520.66699219,
#            519.38568115, 516.16699219]),
#     'tail.1': array([197.57263184, 197.50878906, 197.94165039, ..., 159.9016571 ,
#            159.09893799, 140.80389404])},
#    '60': {'headR': array([215.02516174, 216.92733765, 220.7401123 , ..., 352.78881836,
#            356.13024902, 358.37600708]),
#     'headR.1': array([396.58123779, 400.18658447, 401.21749878, ..., 231.09658813,
#            232.0116272 , 233.10282898]),
#     'headL': array([239.33540344, 242.08468628, 244.17333984, ..., 378.18112183,
#            381.35836792, 382.88955688]),
#     'headL.1': array([397.67877197, 396.546875  , 396.47961426, ..., 227.10908508,
#            227.3731842 , 227.88026428]),
#     'mid1': array([233.25137329, 234.02565002, 236.18273926, ..., 361.78448486,
#            363.05227661, 366.07958984]),
#     'mid1.1': array([372.66195679, 373.72238159, 374.39431763, ..., 202.29972839,
#            204.38427734, 206.40716553]),
#     'mid2': array([259.10638428, 259.43237305, 260.12451172, ..., 369.25372314,
#            368.38842773, 369.6776123 ]),
#     'mid2.1': array([354.61300659, 353.93463135, 353.65750122, ..., 171.94238281,
#            172.38813782, 172.59066772]),
#     'tail': array([278.20941162, 278.52706909, 279.18139648, ..., 384.71774292,
#            384.58026123, 384.27905273]),
#     'tail.1': array([360.709198  , 360.33242798, 360.23327637, ..., 161.66120911,
#            161.11735535, 160.85678101])}},
#   'treatment': 'LID',
#   'id': '22',
#   'ar0': 99.59100262491634},
#  '27_LID': {'traces': {'10': {'headR': array([331.9324646 , 330.96395874, 329.7026062 , ..., 282.58773804,
#            280.60253906, 279.32070923]),
#     'headR.1': array([305.74102783, 306.32415771, 307.59954834, ..., 358.82580566,
#            356.29901123, 352.13372803]),
#     'headL': array([327.48132324, 326.28393555, 325.79602051, ..., 272.13256836,
#            268.94314575, 268.19958496]),
#     'headL.1': array([320.58474731, 322.10760498, 324.00827026, ..., 345.19906616,
#            341.9258728 , 343.12838745]),
#     'mid1': array([346.34890747, 346.08044434, 346.63986206, ..., 250.28242493,
#            251.69581604, 252.05148315]),
#     'mid1.1': array([318.2918396 , 318.74761963, 318.82125854, ..., 365.01620483,
#            363.73117065, 361.27005005]),
#     'mid2': array([378.19390869, 378.77832031, 378.65344238, ..., 226.53918457,
#            227.14866638, 228.46850586]),
#     'mid2.1': array([325.43017578, 326.01806641, 325.58703613, ..., 371.08187866,
#            375.73406982, 378.50390625]),
#     'tail': array([382.80801392, 382.98529053, 383.46365356, ..., 239.04527283,
#            238.80360413, 240.63221741]),
#     'tail.1': array([340.92111206, 340.9831543 , 341.05889893, ..., 344.39654541,
#            346.49273682, 347.55554199])},
#    '50': {'headR': array([314.65628052, 314.13064575, 314.17645264, ..., 367.76290894,
#            367.8934021 , 367.39859009]),
#     'headR.1': array([117.69207764, 119.61829376, 120.3338623 , ..., 259.14794922,
#            259.45123291, 257.03067017]),
#     'headL': array([310.92675781, 311.67037964, 313.25680542, ..., 345.21923828,
#            344.81945801, 344.68051147]),
#     'headL.1': array([136.65890503, 138.60725403, 140.95521545, ..., 254.16516113,
#            254.24993896, 254.39884949]),
#     'mid1': array([338.32583618, 338.7492981 , 338.8336792 , ..., 348.78536987,
#            349.72741699, 349.79144287]),
#     'mid1.1': array([133.49688721, 132.77352905, 132.29615784, ..., 282.53561401,
#            282.52416992, 282.1421814 ]),
#     'mid2': array([365.22634888, 366.26605225, 366.47125244, ..., 332.75177002,
#            333.41812134, 333.57632446]),
#     'mid2.1': array([147.1072998 , 145.91082764, 144.74790955, ..., 306.36584473,
#            305.69018555, 306.18841553]),
#     'tail': array([307.63442993, 307.4486084 , 307.54342651, ..., 365.84762573,
#            365.72463989, 365.80126953]),
#     'tail.1': array([115.00111389, 115.7143631 , 116.45076752, ..., 257.43942261,
#            257.2086792 , 257.36312866])},
#    '20': {'headR': array([220.36399841, 219.62425232, 219.35733032, ..., 266.3274231 ,
#            270.93981934, 275.95452881]),
#     'headR.1': array([ 59.80171967,  61.87245941,  62.77576828, ..., 301.10299683,
#            311.79949951, 320.71850586]),
#     'headL': array([195.49308777, 193.99865723, 191.97877502, ..., 275.355896  ,
#            288.07107544, 297.47384644]),
#     'headL.1': array([ 65.68120575,  67.33184052,  66.64557648, ..., 320.47714233,
#            327.60058594, 330.050354  ]),
#     'mid1': array([214.67628479, 213.3659668 , 212.42196655, ..., 290.86047363,
#            296.03582764, 297.3692627 ]),
#     'mid1.1': array([ 85.27574158,  86.25453949,  85.75286102, ..., 302.61968994,
#            306.39813232, 307.17608643]),
#     'mid2': array([209.43731689, 209.1113739 , 209.02172852, ..., 323.75161743,
#            327.77148438, 328.12872314]),
#     'mid2.1': array([122.45226288, 122.99698639, 122.65740204, ..., 307.6394043 ,
#            300.74035645, 295.11767578]),
#     'tail': array([228.70855713, 225.75326538, 225.28366089, ..., 339.80169678,
#            341.04550171, 345.05383301]),
#     'tail.1': array([ 64.71461487,  64.1062851 ,  64.06768799, ..., 317.29284668,
#            309.06668091, 301.69311523])},
#    '90': {'headR': array([281.74703979, 281.50115967, 281.8230896 , ..., 199.11871338,
#            199.70391846, 203.56990051]),
#     'headR.1': array([390.19799805, 390.12161255, 389.83840942, ..., 387.52304077,
#            388.13000488, 386.32183838]),
#     'headL': array([298.37393188, 298.24822998, 298.06637573, ..., 211.03567505,
#            211.90660095, 212.28479004]),
#     'headL.1': array([401.42895508, 402.30227661, 403.1182251 , ..., 369.64535522,
#            368.83465576, 367.14755249]),
#     'mid1': array([302.03109741, 302.05239868, 301.97189331, ..., 188.21986389,
#            188.37107849, 188.98838806]),
#     'mid1.1': array([375.3883667 , 376.54135132, 377.02764893, ..., 364.75357056,
#            364.56912231, 363.95507812]),
#     'mid2': array([312.51199341, 313.13751221, 312.72607422, ..., 173.05308533,
#            172.9695282 , 172.23782349]),
#     'mid2.1': array([351.59753418, 352.61505127, 352.05172729, ..., 327.09689331,
#            326.91955566, 327.14086914]),
#     'tail': array([276.79263306, 273.37988281, 277.19558716, ..., 182.48022461,
#            183.18791199, 183.65718079]),
#     'tail.1': array([408.99432373, 409.97900391, 408.13485718, ..., 307.83404541,
#            308.0255127 , 308.47891235])},
#    '30': {'headR': array([246.62850952, 245.74105835, 245.05036926, ..., 220.58432007,
#            229.24258423, 233.62265015]),
#     'headR.1': array([337.58673096, 338.362854  , 337.64144897, ..., 226.5806427 ,
#            227.40934753, 228.01489258]),
#     'headL': array([228.26966858, 227.29373169, 224.60420227, ..., 243.1746521 ,
#            247.97546387, 254.94543457]),
#     'headL.1': array([330.31716919, 331.90432739, 332.55374146, ..., 219.42597961,
#            217.90196228, 216.59014893]),
#     'mid1': array([225.02806091, 225.20278931, 225.45895386, ..., 226.50875854,
#            230.98022461, 235.00428772]),
#     'mid1.1': array([355.88534546, 356.43612671, 356.88616943, ..., 201.3812561 ,
#            202.78768921, 202.97872925]),
#     'mid2': array([200.00848389, 200.31057739, 201.84680176, ..., 240.77915955,
#            241.17955017, 243.42803955]),
#     'mid2.1': array([365.29244995, 368.77459717, 371.08673096, ..., 173.38830566,
#            172.01818848, 173.15914917]),
#     'tail': array([244.37588501, 244.38243103, 242.71578979, ..., 217.94464111,
#            218.92524719, 216.71934509]),
#     'tail.1': array([327.52612305, 327.11132812, 328.93069458, ..., 230.82620239,
#            226.97814941, 222.4382782 ])},
#    '80': {'headR': array([356.10324097, 352.03430176, 348.06036377, ..., 360.95974731,
#            360.80712891, 361.07537842]),
#     'headR.1': array([235.24079895, 238.34951782, 241.55415344, ..., 299.5814209 ,
#            299.92245483, 299.72860718]),
#     'headL': array([349.72140503, 348.05975342, 345.34771729, ..., 356.43710327,
#            356.56411743, 356.93130493]),
#     'headL.1': array([252.90722656, 255.85270691, 261.74053955, ..., 321.6991272 ,
#            321.85684204, 322.1322937 ]),
#     'mid1': array([369.70678711, 368.76947021, 366.15661621, ..., 379.93652344,
#            379.90252686, 380.19735718]),
#     'mid1.1': array([249.68287659, 251.91435242, 256.49554443, ..., 314.847229  ,
#            314.77481079, 314.85519409]),
#     'mid2': array([394.59835815, 395.48403931, 395.2567749 , ..., 399.63983154,
#            400.08666992, 399.99969482]),
#     'mid2.1': array([269.89505005, 269.7572937 , 270.61587524, ..., 334.09591675,
#            334.09347534, 334.31103516]),
#     'tail': array([402.80810547, 402.44061279, 402.34942627, ..., 372.18460083,
#            372.48648071, 372.64239502]),
#     'tail.1': array([295.90002441, 293.49749756, 292.71246338, ..., 350.00595093,
#            349.80386353, 349.90039062])},
#    '40': {'headR': array([136.93411255, 137.59094238, 138.23165894, ..., 169.87014771,
#            170.73153687, 171.14193726]),
#     'headR.1': array([303.01327515, 302.05761719, 301.59970093, ..., 164.79992676,
#            164.36654663, 164.48965454]),
#     'headL': array([156.19009399, 156.79246521, 157.6736145 , ..., 158.27102661,
#            158.67262268, 159.03271484]),
#     'headL.1': array([311.47412109, 311.64111328, 312.16104126, ..., 180.60270691,
#            180.20587158, 180.51690674]),
#     'mid1': array([156.4541626 , 156.45742798, 157.12013245, ..., 178.051651  ,
#            178.55557251, 179.02262878]),
#     'mid1.1': array([280.7093811 , 280.92410278, 281.60403442, ..., 182.2454071 ,
#            182.37136841, 182.7212677 ]),
#     'mid2': array([178.80815125, 179.85533142, 180.09770203, ..., 209.46772766,
#            209.13487244, 209.34915161]),
#     'mid2.1': array([258.69073486, 260.59490967, 260.94332886, ..., 195.37008667,
#            195.42785645, 195.2671051 ]),
#     'tail': array([167.39178467, 167.03065491, 166.48983765, ..., 162.79579163,
#            163.05319214, 163.0664978 ]),
#     'tail.1': array([313.32836914, 313.95309448, 314.75906372, ..., 145.36917114,
#            144.77658081, 144.05580139])},
#    '60': {'headR': array([279.96920776, 280.66983032, 281.12646484, ..., 322.62182617,
#            323.27877808, 323.04718018]),
#     'headR.1': array([145.88114929, 145.60397339, 144.44233704, ...,  89.39077759,
#             89.75141907,  89.18387604]),
#     'headL': array([258.78085327, 259.55401611, 260.73971558, ..., 302.94735718,
#            303.14950562, 303.15661621]),
#     'headL.1': array([146.84004211, 146.56455994, 146.73182678, ...,  71.91443634,
#             70.94530487,  70.06874084]),
#     'mid1': array([270.38369751, 270.49285889, 271.01239014, ..., 295.824646  ,
#            295.6050415 , 295.30593872]),
#     'mid1.1': array([174.93057251, 174.66563416, 175.39918518, ...,  92.97000122,
#             92.72729492,  92.67110443]),
#     'mid2': array([263.39318848, 262.54226685, 261.77728271, ..., 271.48120117,
#            271.13235474, 271.55508423]),
#     'mid2.1': array([206.82537842, 206.31900024, 205.83862305, ..., 104.18713379,
#            103.91931152, 103.41856384]),
#     'tail': array([282.56311035, 282.86791992, 283.18417358, ..., 301.67739868,
#            301.49237061, 301.40344238]),
#     'tail.1': array([147.52256775, 147.69493103, 147.28587341, ...,  65.15126801,
#             64.56278229,  64.16808319])},
#    '70': {'headR': array([201.29194641, 200.57948303, 200.53630066, ..., 253.67700195,
#            248.94793701, 243.66134644]),
#     'headR.1': array([299.94165039, 300.81420898, 301.16534424, ..., 339.31646729,
#            336.49493408, 334.93487549]),
#     'headL': array([206.41387939, 206.60113525, 206.73674011, ..., 236.81492615,
#            228.35542297, 224.36962891]),
#     'headL.1': array([278.80221558, 280.55612183, 280.72183228, ..., 332.19085693,
#            331.35961914, 331.70620728]),
#     'mid1': array([176.89685059, 176.82449341, 176.62020874, ..., 236.088974  ,
#            234.00587463, 229.76524353]),
#     'mid1.1': array([280.20297241, 280.25430298, 281.25918579, ..., 352.58752441,
#            348.56326294, 348.87844849]),
#     'mid2': array([153.41496277, 153.41290283, 152.93960571, ..., 200.55628967,
#            201.48381042, 200.08071899]),
#     'mid2.1': array([261.31887817, 261.19570923, 261.48236084, ..., 349.48968506,
#            353.78225708, 359.0909729 ]),
#     'tail': array([201.36933899, 201.18927002, 201.09925842, ..., 185.37713623,
#            184.60754395, 184.93978882]),
#     'tail.1': array([302.78656006, 303.1348877 , 303.38818359, ..., 339.50442505,
#            344.69497681, 351.23471069])}},
#   'treatment': 'LID',
#   'id': '27',
#   'ar0': 85.76731965379025},
#  '23_LID': {'traces': {'30': {'headR': array([303.50552368, 303.8732605 , 303.78677368, ..., 292.55722046,
#            289.57537842, 285.89224243]),
#     'headR.1': array([220.76916504, 220.65986633, 219.8684082 , ..., 103.73986053,
#            105.83053589, 108.10778809]),
#     'headL': array([306.17950439, 306.80404663, 307.08822632, ..., 275.7706604 ,
#            274.10836792, 272.19418335]),
#     'headL.1': array([247.73928833, 247.40200806, 247.10334778, ..., 122.61901855,
#            125.42873383, 128.34095764]),
#     'mid1': array([329.18692017, 329.61618042, 329.934021  , ..., 300.77249146,
#            298.98297119, 297.50219727]),
#     'mid1.1': array([223.67449951, 223.72155762, 222.89471436, ..., 128.32281494,
#            128.08699036, 129.67054749]),
#     'mid2': array([357.38162231, 357.62911987, 357.78250122, ..., 317.79968262,
#            317.93435669, 314.87435913]),
#     'mid2.1': array([222.09393311, 222.28086853, 221.46069336, ..., 162.46347046,
#            161.22686768, 159.20623779]),
#     'tail': array([361.55303955, 361.40283203, 361.3293457 , ..., 327.23623657,
#            330.90072632, 332.90789795]),
#     'tail.1': array([244.89772034, 244.83106995, 244.67701721, ..., 196.19180298,
#            194.50657654, 193.25042725])},
#    '70': {'headR': array([460.26821899, 460.61706543, 460.08724976, ..., 161.45726013,
#            162.16496277, 162.03494263]),
#     'headR.1': array([141.31245422, 141.18002319, 140.97636414, ..., 260.5194397 ,
#            261.74450684, 263.45727539]),
#     'headL': array([456.95840454, 457.12860107, 456.50524902, ..., 184.35902405,
#            185.79992676, 186.64682007]),
#     'headL.1': array([114.82334137, 115.0133667 , 114.28646851, ..., 263.43701172,
#            264.63964844, 265.55361938]),
#     'mid1': array([435.46151733, 435.6937561 , 435.41015625, ..., 171.2353363 ,
#            171.52006531, 171.83422852]),
#     'mid1.1': array([127.47442627, 127.42461395, 126.94781494, ..., 222.06134033,
#            223.36502075, 224.69390869]),
#     'mid2': array([397.60879517, 398.07861328, 398.20043945, ..., 187.0007019 ,
#            187.59017944, 187.90292358]),
#     'mid2.1': array([117.44517517, 117.07147217, 116.88631439, ..., 180.30569458,
#            181.7247467 , 184.16918945]),
#     'tail': array([364.82006836, 365.48794556, 366.02554321, ..., 187.11868286,
#            186.80604553, 186.68251038]),
#     'tail.1': array([120.57151031, 120.9414978 , 120.69921875, ..., 152.98669434,
#            156.26698303, 157.40194702])},
#    '20': {'headR': array([269.49050903, 259.86114502, 247.79653931, ..., 278.93521118,
#            277.43859863, 277.28372192]),
#     'headR.1': array([111.77545166, 117.17635345, 122.65620422, ..., 181.17980957,
#            192.50744629, 205.2155304 ]),
#     'headL': array([254.14265442, 245.58557129, 238.79463196, ..., 291.64755249,
#            294.85028076, 297.42953491]),
#     'headL.1': array([131.65896606, 138.11810303, 146.58673096, ..., 200.84983826,
#            209.59315491, 218.39422607]),
#     'mid1': array([279.10830688, 271.14260864, 263.77328491, ..., 308.10028076,
#            305.54428101, 304.40289307]),
#     'mid1.1': array([137.79370117, 141.02537537, 144.10090637, ..., 174.15467834,
#            177.45663452, 182.37414551]),
#     'mid2': array([280.77566528, 279.67459106, 280.31665039, ..., 343.99719238,
#            341.46868896, 340.49404907]),
#     'mid2.1': array([174.14579773, 173.27622986, 175.89013672, ..., 178.41014099,
#            174.63305664, 172.21365356]),
#     'tail': array([264.82034302, 268.5368042 , 275.43688965, ..., 366.55358887,
#            367.37518311, 365.12173462]),
#     'tail.1': array([207.72601318, 210.08520508, 212.46313477, ..., 192.10241699,
#            186.08692932, 180.65618896])},
#    '10': {'headR': array([355.94818115, 356.73880005, 356.79663086, ..., 230.73902893,
#            231.78286743, 233.87234497]),
#     'headR.1': array([175.36213684, 176.10426331, 175.59373474, ..., 132.61489868,
#            141.7150116 , 148.3465271 ]),
#     'headL': array([341.34518433, 341.85073853, 341.47576904, ..., 246.04388428,
#            249.03619385, 253.73049927]),
#     'headL.1': array([191.81791687, 191.93382263, 191.37333679, ..., 152.57435608,
#            159.02069092, 161.39710999]),
#     'mid1': array([373.00765991, 372.87493896, 371.57449341, ..., 260.21221924,
#            257.28417969, 259.26803589]),
#     'mid1.1': array([197.800354  , 198.79411316, 198.45567322, ..., 127.53585815,
#            132.87774658, 133.81947327]),
#     'mid2': array([415.0824585 , 414.92990112, 412.54440308, ..., 296.31234741,
#            294.82363892, 295.91976929]),
#     'mid2.1': array([224.59919739, 226.69219971, 226.56130981, ..., 138.42019653,
#            134.68051147, 132.98664856]),
#     'tail': array([436.83657837, 435.49295044, 435.28500366, ..., 309.65145874,
#            314.027771  , 317.41342163]),
#     'tail.1': array([223.81343079, 224.07684326, 224.73681641, ..., 168.41812134,
#            163.72808838, 157.68754578])},
#    '50': {'headR': array([330.08474731, 328.87765503, 329.51727295, ..., 373.2076416 ,
#            376.41052246, 377.35040283]),
#     'headR.1': array([262.51531982, 267.65768433, 273.84979248, ..., 189.56758118,
#            185.96807861, 184.51858521]),
#     'headL': array([346.79049683, 348.75338745, 351.97900391, ..., 369.9486084 ,
#            370.91931152, 371.29559326]),
#     'headL.1': array([279.21832275, 283.68112183, 286.8732605 , ..., 165.42658997,
#            162.47729492, 160.35910034]),
#     'mid1': array([355.54382324, 356.39538574, 355.06118774, ..., 349.88766479,
#            351.08520508, 352.35003662]),
#     'mid1.1': array([252.10906982, 253.58372498, 256.12133789, ..., 178.82157898,
#            177.24468994, 176.52313232]),
#     'mid2': array([393.44537354, 394.54107666, 391.98242188, ..., 307.64526367,
#            309.83529663, 312.10678101]),
#     'mid2.1': array([248.60266113, 249.16603088, 249.97834778, ..., 165.82958984,
#            167.20646667, 170.35249329]),
#     'tail': array([409.35684204, 410.81610107, 411.36807251, ..., 284.37789917,
#            284.29837036, 283.2144165 ]),
#     'tail.1': array([273.87350464, 269.2784729 , 266.78482056, ..., 143.58982849,
#            147.37341309, 151.6555481 ])},
#    '90': {'headR': array([230.16217041, 229.24195862, 228.87451172, ..., 326.31356812,
#            326.04745483, 325.97106934]),
#     'headR.1': array([129.82691956, 129.08050537, 128.81542969, ..., 181.59115601,
#            181.60958862, 181.77159119]),
#     'headL': array([220.27110291, 220.58642578, 220.90982056, ..., 309.30795288,
#            308.8664856 , 308.81390381]),
#     'headL.1': array([114.22783661, 115.62290955, 116.32749939, ..., 198.93161011,
#            198.99488831, 198.99621582]),
#     'mid1': array([208.92697144, 208.53108215, 208.66464233, ..., 329.68457031,
#            329.93621826, 329.9770813 ]),
#     'mid1.1': array([140.01376343, 140.32591248, 140.42150879, ..., 209.24319458,
#            209.0534668 , 209.06192017]),
#     'mid2': array([184.41398621, 184.63883972, 183.75764465, ..., 339.8432312 ,
#            340.06469727, 340.36883545]),
#     'mid2.1': array([169.11106873, 169.13961792, 168.42678833, ..., 247.05303955,
#            246.99165344, 247.16285706]),
#     'tail': array([238.21110535, 237.60653687, 238.06326294, ..., 346.97674561,
#            346.76544189, 346.76525879]),
#     'tail.1': array([138.59388733, 139.16401672, 139.40142822, ..., 265.68869019,
#            265.58596802, 266.08456421])},
#    '80': {'headR': array([467.76467896, 467.82388306, 467.87466431, ..., 266.98721313,
#            267.15200806, 267.40750122]),
#     'headR.1': array([230.92073059, 231.05438232, 231.19075012, ..., 148.77075195,
#            148.60037231, 147.23857117]),
#     'headL': array([468.81799316, 468.50653076, 468.67785645, ..., 271.59570312,
#            271.89379883, 272.09002686]),
#     'headL.1': array([206.61412048, 206.68148804, 206.84854126, ..., 123.82344818,
#            124.39358521, 124.11920929]),
#     'mid1': array([449.60372925, 449.63375854, 449.56997681, ..., 240.79771423,
#            240.1211853 , 241.17399597]),
#     'mid1.1': array([220.99864197, 221.14299011, 221.24105835, ..., 120.36483765,
#            120.42463684, 120.63321686]),
#     'mid2': array([412.65542603, 412.77880859, 412.61529541, ..., 227.54463196,
#            228.00538635, 227.53172302]),
#     'mid2.1': array([238.14317322, 238.45597839, 238.45181274, ...,  82.85958099,
#             82.29227448,  83.39258575]),
#     'tail': array([406.98233032, 407.10531616, 406.77563477, ..., 244.85786438,
#            245.13388062, 244.09822083]),
#     'tail.1': array([270.70501709, 270.80703735, 270.86434937, ...,  73.43126678,
#             73.73184204,  73.40227509])},
#    '60': {'headR': array([358.02841187, 354.7177124 , 350.36264038, ..., 259.96640015,
#            261.63745117, 262.79486084]),
#     'headR.1': array([102.81425476, 104.40260315, 106.18743896, ..., 205.22003174,
#            209.08740234, 211.08631897]),
#     'headL': array([339.87741089, 338.00259399, 334.8097229 , ..., 284.19869995,
#            285.75183105, 287.76083374]),
#     'headL.1': array([118.96997833, 121.24508667, 123.98467255, ..., 218.95207214,
#            222.54725647, 224.11627197]),
#     'mid1': array([365.5508728 , 364.20996094, 363.36901855, ..., 296.88574219,
#            296.39529419, 297.20269775]),
#     'mid1.1': array([124.8802948 , 126.83617401, 129.6776886 , ..., 186.24551392,
#            189.18334961, 189.30760193]),
#     'mid2': array([387.46282959, 388.23684692, 388.52102661, ..., 333.85580444,
#            335.54492188, 337.534729  ]),
#     'mid2.1': array([158.68954468, 159.46357727, 160.65634155, ..., 193.359375  ,
#            191.47621155, 190.45036316]),
#     'tail': array([405.31088257, 405.05508423, 405.33081055, ..., 350.49890137,
#            352.34918213, 353.65603638]),
#     'tail.1': array([194.68447876, 194.66836548, 194.49504089, ..., 204.52983093,
#            202.14768982, 199.00492859])},
#    '40': {'headR': array([339.1574707 , 340.45962524, 343.65255737, ..., 408.78723145,
#            408.63754272, 408.59823608]),
#     'headR.1': array([250.9152832 , 252.31973267, 255.17958069, ..., 195.69927979,
#            195.63928223, 196.0176239 ]),
#     'headL': array([358.92559814, 360.55783081, 366.09243774, ..., 380.28778076,
#            380.11810303, 380.07885742]),
#     'headL.1': array([263.9586792 , 265.05264282, 266.30517578, ..., 190.85180664,
#            190.76696777, 190.72737122]),
#     'mid1': array([361.33990479, 363.1555481 , 366.37414551, ..., 387.3911438 ,
#            387.5116272 , 386.80371094]),
#     'mid1.1': array([228.79315186, 229.86206055, 231.5677948 , ..., 216.00033569,
#            216.11216736, 215.40344238]),
#     'mid2': array([392.69262695, 394.55377197, 395.08761597, ..., 357.59259033,
#            357.67004395, 357.5859375 ]),
#     'mid2.1': array([200.22407532, 201.91459656, 202.64216614, ..., 243.11283875,
#            243.53540039, 243.39027405]),
#     'tail': array([413.52044678, 413.23068237, 413.18356323, ..., 350.19512939,
#            349.86807251, 349.88592529]),
#     'tail.1': array([183.55055237, 183.1275177 , 183.17964172, ..., 218.26785278,
#            217.92520142, 218.07194519])}},
#   'treatment': 'LID',
#   'id': '23',
#   'ar0': 105.46565354521928},
#  '25_LID': {'traces': {'10': {'headR': array([208.41775513, 210.17427063, 211.31105042, ..., 392.06677246,
#            393.35067749, 393.60476685]),
#     'headR.1': array([339.13571167, 342.81716919, 343.62664795, ..., 317.00054932,
#            318.13391113, 318.60067749]),
#     'headL': array([229.43891907, 230.9833374 , 232.16374207, ..., 412.04382324,
#            412.93487549, 413.93792725]),
#     'headL.1': array([328.17276001, 330.99679565, 331.65713501, ..., 323.67172241,
#            325.30743408, 327.12136841]),
#     'mid1': array([206.38473511, 208.62870789, 208.8555603 , ..., 413.48522949,
#            414.53839111, 415.49499512]),
#     'mid1.1': array([304.19519043, 307.48059082, 308.26885986, ..., 287.2376709 ,
#            287.17156982, 288.20654297]),
#     'mid2': array([206.0664978 , 204.05821228, 202.50790405, ..., 443.38110352,
#            443.81365967, 443.79379272]),
#     'mid2.1': array([257.46786499, 259.69076538, 260.4234314 , ..., 264.91281128,
#            264.04772949, 263.75048828]),
#     'tail': array([197.1427002 , 191.38200378, 190.12591553, ..., 462.41247559,
#            462.60244751, 461.99176025]),
#     'tail.1': array([236.36579895, 238.89903259, 239.49781799, ..., 264.56945801,
#            263.31384277, 262.8555603 ])},
#    '80': {'headR': array([298.99789429, 296.36434937, 294.15817261, ..., 426.92977905,
#            429.38601685, 430.53271484]),
#     'headR.1': array([ 90.35858917,  90.33538818,  88.60124207, ..., 205.7467804 ,
#            202.23800659, 200.08078003]),
#     'headL': array([275.4564209 , 273.12237549, 273.37228394, ..., 426.90875244,
#            428.30349731, 428.02841187]),
#     'headL.1': array([ 91.66804504,  90.94219208,  89.21565247, ..., 183.00135803,
#            178.68626404, 176.33703613]),
#     'mid1': array([285.80007935, 284.55273438, 283.58581543, ..., 403.78704834,
#            405.35644531, 406.59402466]),
#     'mid1.1': array([114.60746765, 113.68917084, 113.11616516, ..., 193.63179016,
#            191.23416138, 189.42596436]),
#     'mid2': array([268.78964233, 269.05780029, 268.26669312, ..., 369.2270813 ,
#            368.43026733, 369.13272095]),
#     'mid2.1': array([144.90698242, 145.10986328, 145.15858459, ..., 175.93714905,
#            177.01307678, 178.32055664]),
#     'tail': array([245.83789062, 247.92779541, 248.93501282, ..., 360.16223145,
#            357.53573608, 355.68899536]),
#     'tail.1': array([165.74787903, 167.1217804 , 169.71554565, ..., 152.36447144,
#            154.02879333, 156.77423096])},
#    '20': {'headR': array([421.97607422, 420.88327026, 419.40771484, ..., 384.97885132,
#            385.45046997, 385.75634766]),
#     'headR.1': array([257.14953613, 258.84832764, 260.37634277, ..., 291.90594482,
#            291.50714111, 291.44674683]),
#     'headL': array([406.63296509, 405.75567627, 405.14849854, ..., 411.347229  ,
#            411.41586304, 411.91830444]),
#     'headL.1': array([277.80123901, 280.20849609, 281.42572021, ..., 290.61459351,
#            290.18212891, 290.09436035]),
#     'mid1': array([431.55776978, 432.73257446, 432.7109375 , ..., 396.63470459,
#            396.31445312, 396.73535156]),
#     'mid1.1': array([287.11135864, 288.75314331, 288.73306274, ..., 259.71987915,
#            259.98596191, 259.70874023]),
#     'mid2': array([432.61990356, 434.67626953, 437.18231201, ..., 405.36804199,
# ...
#            225.41107178, 225.67182922]),
#     'headL': array([111.1042099 , 112.43301392, 114.05312347, ...,  68.97503662,
#             69.62796783,  67.62740326]),
#     'headL.1': array([236.77430725, 239.55180359, 241.36967468, ..., 230.24125671,
#            228.4886322 , 228.08534241]),
#     'mid1': array([124.12138367, 124.18916321, 124.53746033, ...,  83.5136261 ,
#             83.96407318,  83.35604095]),
#     'mid1.1': array([215.0799408 , 216.72741699, 217.69038391, ..., 247.99519348,
#            246.85588074, 247.57344055]),
#     'mid2': array([158.65638733, 158.01535034, 156.8144989 , ...,  86.83102417,
#             86.10391998,  86.77794647]),
#     'mid2.1': array([202.58580017, 202.45976257, 204.46025085, ..., 269.61257935,
#            269.43115234, 268.14331055]),
#     'tail': array([100.56865692, 101.00248718, 105.4659729 , ...,  66.57113647,
#             67.39808655,  68.40826416]),
#     'tail.1': array([208.59988403, 210.99073792, 204.03199768, ..., 217.58006287,
#            215.6986084 , 214.89295959])},
#    '90': {'headR': array([318.16888428, 318.06021118, 317.71966553, ..., 302.35894775,
#            302.01147461, 301.88470459]),
#     'headR.1': array([190.31761169, 190.23873901, 190.0738678 , ..., 133.05865479,
#            133.12677002, 132.76628113]),
#     'headL': array([296.37487793, 296.40783691, 296.37503052, ..., 281.97085571,
#            281.63189697, 281.58682251]),
#     'headL.1': array([187.45150757, 187.38612366, 187.51539612, ..., 119.90040588,
#            120.17938232, 120.04542542]),
#     'mid1': array([304.74737549, 304.99786377, 304.65280151, ..., 280.12869263,
#            279.95837402, 280.02999878]),
#     'mid1.1': array([208.32684326, 208.63885498, 208.42214966, ..., 143.80638123,
#            143.98449707, 143.90309143]),
#     'mid2': array([291.48376465, 291.46566772, 291.49118042, ..., 258.44497681,
#            258.5333252 , 258.37496948]),
#     'mid2.1': array([239.42132568, 239.79759216, 239.86257935, ..., 172.460495  ,
#            172.4487915 , 172.3412323 ]),
#     'tail': array([278.98739624, 278.84039307, 278.97506714, ..., 256.03918457,
#            256.12307739, 255.90039062]),
#     'tail.1': array([256.64782715, 256.69335938, 256.58795166, ..., 192.84396362,
#            192.85998535, 192.8969574 ])},
#    '40': {'headR': array([ 96.67796326,  97.2556076 ,  99.2888031 , ..., 111.05312347,
#            112.08161926, 112.51834106]),
#     'headR.1': array([290.20648193, 290.66461182, 290.8659668 , ..., 304.56469727,
#            305.45953369, 306.44854736]),
#     'headL': array([ 80.29336548,  80.0684433 ,  81.92624664, ..., 101.33978271,
#            103.32487488, 103.74323273]),
#     'headL.1': array([305.02923584, 304.44387817, 302.06686401, ..., 323.73709106,
#            324.43469238, 325.50442505]),
#     'mid1': array([ 98.24511719, 100.20546722, 101.97459412, ..., 125.52254486,
#            126.76034546, 127.07104492]),
#     'mid1.1': array([312.49969482, 311.02676392, 310.1267395 , ..., 328.14807129,
#            327.64987183, 328.40863037]),
#     'mid2': array([116.67288971, 115.12100983, 113.93199921, ..., 133.37509155,
#            134.72976685, 135.35166931]),
#     'mid2.1': array([328.73348999, 329.5295105 , 330.55715942, ..., 352.41635132,
#            352.26751709, 352.0675354 ]),
#     'tail': array([76.44806671, 77.06549835, 76.71522522, ..., 91.70042419,
#            91.94483948, 91.81803131]),
#     'tail.1': array([287.25064087, 288.52801514, 288.59841919, ..., 315.45584106,
#            315.64157104, 316.07995605])},
#    '50': {'headR': array([367.17300415, 368.18499756, 366.42684937, ..., 262.19387817,
#            266.98419189, 270.44046021]),
#     'headR.1': array([204.21437073, 199.79470825, 194.88648987, ..., 153.95799255,
#            151.16563416, 147.39529419]),
#     'headL': array([356.39904785, 353.36047363, 349.81549072, ..., 280.60604858,
#            281.27301025, 284.60287476]),
#     'headL.1': array([188.58822632, 186.77433777, 183.23327637, ..., 142.58598328,
#            135.90397644, 131.98402405]),
#     'mid1': array([338.8939209 , 338.57434082, 336.82449341, ..., 258.51812744,
#            258.58285522, 260.15423584]),
#     'mid1.1': array([208.49577332, 208.03823853, 205.71450806, ..., 126.59415436,
#            123.85541534, 121.84788513]),
#     'mid2': array([310.52087402, 309.08529663, 307.42242432, ..., 272.19689941,
#            266.07217407, 263.32073975]),
#     'mid2.1': array([212.92970276, 214.09283447, 214.7585144 , ...,  93.05261993,
#             90.88704681,  89.35441589]),
#     'tail': array([364.27246094, 367.14450073, 368.52505493, ..., 290.55926514,
#            285.80169678, 281.53292847]),
#     'tail.1': array([224.00491333, 216.24076843, 211.32092285, ...,  92.18256378,
#             88.55735016,  84.67538452])}},
#   'treatment': 'LID',
#   'id': '28',
#   'ar0': 88.94917439563875},
#  '21_LID': {'traces': {'20': {'headR': array([353.37652588, 353.6776123 , 354.29141235, ..., 449.6328125 ,
#            452.71716309, 456.47589111]),
#     'headR.1': array([382.56954956, 381.87493896, 380.49746704, ..., 198.53848267,
#            199.46961975, 200.66648865]),
#     'headL': array([352.78417969, 352.21276855, 351.09225464, ..., 467.63656616,
#            471.83578491, 475.65908813]),
#     'headL.1': array([358.46240234, 358.43688965, 357.31085205, ..., 218.38212585,
#            217.8785553 , 220.9427948 ]),
#     'mid1': array([321.08666992, 318.60931396, 316.34237671, ..., 487.59536743,
#            489.39807129, 491.47940063]),
#     'mid1.1': array([363.17913818, 361.41894531, 362.1930542 , ..., 189.88606262,
#            190.98703003, 192.05734253]),
#     'mid2': array([299.07601929, 297.68991089, 297.99337769, ..., 521.97674561,
#            525.14788818, 526.59741211]),
#     'mid2.1': array([330.63586426, 330.54696655, 330.20492554, ..., 198.84629822,
#            195.82929993, 189.94746399]),
#     'tail': array([341.25463867, 341.56286621, 342.39602661, ..., 533.07641602,
#            535.90838623, 536.4942627 ]),
#     'tail.1': array([335.70858765, 336.14862061, 335.58691406, ..., 216.35263062,
#            212.60862732, 210.4208374 ])},
#    '30': {'headR': array([410.26818848, 408.28994751, 407.86669922, ..., 223.71455383,
#            223.62789917, 223.6912384 ]),
#     'headR.1': array([180.41792297, 180.51283264, 180.53025818, ...,  82.97858429,
#             83.46883392,  82.92726898]),
#     'headL': array([417.43951416, 415.7649231 , 414.84472656, ..., 242.65783691,
#            241.33805847, 242.99464417]),
#     'headL.1': array([205.83102417, 204.81770325, 204.55142212, ...,  91.39481354,
#             90.27232361,  91.66517639]),
#     'mid1': array([445.16101074, 444.46307373, 443.59118652, ..., 226.5528717 ,
#            225.66644287, 226.79322815]),
#     'mid1.1': array([189.59275818, 189.70121765, 190.08618164, ...,  88.29602051,
#             88.64381409,  92.13806915]),
#     'mid2': array([457.92398071, 457.49252319, 457.06738281, ..., 198.98654175,
#            203.90711975, 197.76994324]),
#     'mid2.1': array([224.20581055, 223.8379364 , 223.70483398, ...,  93.16480255,
#             98.23217773,  93.01116943]),
#     'tail': array([426.96957397, 427.27346802, 427.6232605 , ..., 231.71902466,
#            230.92788696, 231.16711426]),
#     'tail.1': array([225.77597046, 225.78153992, 225.69186401, ...,  51.2748909 ,
#             51.44429016,  51.1927681 ])},
#    '60': {'headR': array([231.93238831, 234.24009705, 236.6595459 , ..., 452.31045532,
#            454.8588562 , 457.56854248]),
#     'headR.1': array([295.45959473, 298.47634888, 300.52224731, ..., 328.85519409,
#            328.57382202, 328.62277222]),
#     'headL': array([256.64907837, 257.53579712, 259.55905151, ..., 448.01318359,
#            449.94573975, 453.43011475]),
#     'headL.1': array([295.89675903, 297.63757324, 299.01885986, ..., 304.88882446,
#            304.8984375 , 304.92868042]),
#     'mid1': array([246.26225281, 246.54924011, 247.80030823, ..., 427.19165039,
#            430.17758179, 433.8059082 ]),
#     'mid1.1': array([262.5269165 , 262.80795288, 263.54754639, ..., 319.73516846,
#            319.85922241, 318.52978516]),
#     'mid2': array([252.31436157, 253.43663025, 253.79144287, ..., 380.45898438,
#            383.1105957 , 387.6444397 ]),
#     'mid2.1': array([218.19857788, 219.69830322, 219.70773315, ..., 325.21801758,
#            325.9430542 , 326.67150879]),
#     'tail': array([258.7322998 , 257.91345215, 257.79232788, ..., 354.5881958 ,
#            356.77468872, 359.12417603]),
#     'tail.1': array([192.52575684, 194.26426697, 195.3291626 , ..., 344.31121826,
#            344.53036499, 344.64645386])},
#    '70': {'headR': array([199.72312927, 199.99458313, 200.42604065, ..., 401.93325806,
#            399.92172241, 399.48040771]),
#     'headR.1': array([355.03613281, 355.06072998, 355.16723633, ..., 317.90682983,
#            318.08407593, 315.82278442]),
#     'headL': array([224.38072205, 224.77587891, 225.14456177, ..., 425.20007324,
#            424.60726929, 424.00881958]),
#     'headL.1': array([355.35452271, 355.52835083, 355.05880737, ..., 319.72494507,
#            321.50021362, 322.14871216]),
#     'mid1': array([215.28782654, 215.86778259, 215.83067322, ..., 411.48358154,
#            409.64099121, 408.57141113]),
#     'mid1.1': array([330.84368896, 330.15365601, 329.89624023, ..., 277.34622192,
#            279.25085449, 280.8522644 ]),
#     'mid2': array([232.98869324, 233.52366638, 233.0553894 , ..., 417.23443604,
#            416.7989502 , 416.46786499]),
#     'mid2.1': array([291.42315674, 291.86575317, 291.45663452, ..., 245.33932495,
#            248.21699524, 246.14768982]),
#     'tail': array([241.5116272 , 241.26347351, 240.92807007, ..., 175.90489197,
#            175.8896637 , 175.80747986]),
#     'tail.1': array([274.94470215, 275.03845215, 274.8934021 , ..., 204.57342529,
#            204.59677124, 204.68948364])},
#    '40': {'headR': array([447.53274536, 447.94793701, 447.54766846, ..., 366.09698486,
#            363.92645264, 361.19018555]),
#     'headR.1': array([129.06784058, 128.42729187, 128.51750183, ...,  91.94926453,
#             89.47869873,  87.36924744]),
#     'headL': array([418.87475586, 418.86303711, 419.01541138, ..., 345.52142334,
#            342.20425415, 336.39349365]),
#     'headL.1': array([118.0584259 , 117.79311371, 117.62973022, ...,  80.73253632,
#             78.53707886,  77.13646698]),
#     'mid1': array([420.86279297, 421.19702148, 421.1920166 , ..., 335.11499023,
#            334.3196106 , 331.90359497]),
#     'mid1.1': array([140.6665802 , 140.22924805, 140.17773438, ..., 104.43647766,
#            102.00421143, 100.52059937]),
#     'mid2': array([400.80789185, 401.22628784, 400.74362183, ..., 298.11132812,
#            297.54788208, 296.40182495]),
#     'mid2.1': array([163.45713806, 162.959198  , 162.82020569, ..., 101.74137115,
#            102.37252808, 104.69096375]),
#     'tail': array([398.24432373, 398.06246948, 397.74908447, ..., 290.5291748 ,
#            289.69976807, 289.35366821]),
#     'tail.1': array([140.19184875, 139.93040466, 139.66514587, ...,  84.86829376,
#             86.01858521,  85.87168884])},
#    '10': {'headR': array([422.60482788, 424.54290771, 426.96307373, ..., 497.96246338,
#            498.41339111, 498.81011963]),
#     'headR.1': array([316.90332031, 319.41836548, 319.74780273, ..., 204.59788513,
#            203.60270691, 202.79922485]),
#     'headL': array([447.3555603 , 451.28274536, 454.46865845, ..., 520.23034668,
#            519.5980835 , 518.62060547]),
#     'headL.1': array([330.47201538, 330.40124512, 329.33325195, ..., 189.87464905,
#            187.16929626, 184.1842041 ]),
#     'mid1': array([455.36044312, 457.71536255, 461.47619629, ..., 499.16876221,
#            498.3550415 , 493.46539307]),
#     'mid1.1': array([299.76516724, 298.17086792, 295.9095459 , ..., 161.31724548,
#            159.95283508, 161.21496582]),
#     'mid2': array([489.34475708, 492.79794312, 494.86233521, ..., 517.91906738,
#            518.394104  , 502.71066284]),
#     'mid2.1': array([303.07095337, 301.58996582, 299.44937134, ..., 134.21661377,
#            132.99978638, 129.06158447]),
#     'tail': array([501.14260864, 503.70980835, 506.46688843, ..., 534.53985596,
#            533.00421143, 529.23248291]),
#     'tail.1': array([324.66677856, 321.8447876 , 318.69064331, ..., 164.07174683,
#            161.60853577, 159.80926514])},
#    '80': {'headR': array([402.37908936, 402.3230896 , 402.19677734, ..., 402.95550537,
#            402.89581299, 402.30282593]),
#     'headR.1': array([187.63398743, 187.36898804, 186.83543396, ..., 272.17340088,
#            273.1817627 , 274.12786865]),
#     'headL': array([421.95755005, 421.23898315, 421.0005188 , ..., 404.79504395,
#            404.9977417 , 405.06048584]),
#     'headL.1': array([201.66873169, 201.88479614, 201.99304199, ..., 298.7081604 ,
#            300.14498901, 301.11425781]),
#     'mid1': array([424.47360229, 424.17807007, 424.27453613, ..., 429.17089844,
#            429.28848267, 429.33892822]),
#     'mid1.1': array([173.99263   , 173.84757996, 174.18682861, ..., 284.98971558,
#            285.60845947, 285.74725342]),
#     'mid2': array([447.67474365, 447.52655029, 448.19659424, ..., 455.44781494,
#            455.58053589, 455.22369385]),
#     'mid2.1': array([142.98986816, 143.73670959, 143.54815674, ..., 296.45413208,
#            296.75891113, 297.44387817]),
#     'tail': array([462.00894165, 461.23403931, 461.86621094, ..., 453.99407959,
#            455.36849976, 455.7053833 ]),
#     'tail.1': array([126.37889862, 126.51337433, 126.56394958, ..., 325.59390259,
#            325.31137085, 325.2880249 ])},
#    '50': {'headR': array([222.72827148, 223.6723175 , 224.74552917, ..., 351.64532471,
#            352.83892822, 353.2147522 ]),
#     'headR.1': array([310.52807617, 310.25314331, 310.92120361, ..., 378.16903687,
#            377.35198975, 377.72961426]),
#     'headL': array([246.81539917, 247.57086182, 249.21389771, ..., 374.47097778,
#            375.527771  , 375.49987793]),
#     'headL.1': array([306.44772339, 304.81054688, 303.94494629, ..., 366.81097412,
#            365.72595215, 366.11099243]),
#     'mid1': array([231.90686035, 232.74337769, 233.36103821, ..., 357.10284424,
#            358.28286743, 358.61621094]),
#     'mid1.1': array([279.12973022, 277.60668945, 277.18597412, ..., 341.66345215,
#            340.62939453, 341.21459961]),
#     'mid2': array([238.85877991, 235.24969482, 235.05059814, ..., 368.17645264,
#            368.93048096, 368.57299805]),
#     'mid2.1': array([240.61325073, 240.12307739, 239.60974121, ..., 311.6574707 ,
#            311.66644287, 311.64852905]),
#     'tail': array([232.25175476, 231.10049438, 230.5864563 , ..., 381.15145874,
#            381.06732178, 381.19161987]),
#     'tail.1': array([217.57823181, 217.25704956, 217.06291199, ..., 294.93231201,
#            294.49645996, 294.09729004])},
#    '90': {'headR': array([431.19747925, 430.02578735, 429.41213989, ..., 512.08148193,
#            511.91442871, 512.1706543 ]),
#     'headR.1': array([239.62095642, 239.38781738, 239.24276733, ..., 169.35604858,
#            169.51422119, 169.0905304 ]),
#     'headL': array([410.66439819, 409.76644897, 407.64544678, ..., 516.45837402,
#            515.93713379, 515.49615479]),
#     'headL.1': array([228.05412292, 228.41522217, 227.87268066, ..., 140.08984375,
#            140.14527893, 140.03710938]),
#     'mid1': array([405.74679565, 405.32565308, 404.57070923, ..., 485.41622925,
#            485.11340332, 484.92651367]),
#     'mid1.1': array([252.96887207, 252.87814331, 253.31056213, ..., 145.37709045,
#            145.24473572, 145.01254272]),
#     'mid2': array([382.23501587, 382.45318604, 382.68652344, ..., 472.2578125 ,
#            471.56304932, 470.77206421]),
#     'mid2.1': array([278.35214233, 278.85101318, 278.81451416, ..., 133.21337891,
#            133.76753235, 135.58551025]),
#     'tail': array([369.43597412, 369.39697266, 369.46697998, ..., 454.84512329,
#            454.8420105 , 454.70761108]),
#     'tail.1': array([296.67672729, 296.89938354, 297.14324951, ..., 168.91099548,
#            169.17658997, 168.89860535])}},
#   'treatment': 'LID',
#   'id': '21',
#   'ar0': 77.70464850659604}}

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


treatment='LD-3mg'
ID_n=5
time_point=30

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('LID_series.svg')
plt.draw()
# Out:
# (7200,)

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


treatment='Vehicle' #color code, Figure2
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('Veh_series.svg')
plt.draw()
# Out:
# (7200,)

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)


treatment='D2Ag' #color
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D2Ag_series.svg')
plt.draw()
# Out:
# (7200,)

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)


treatment='D1Ag' #color
ID_n=3
time_point=10

strt=10
fini=30
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D1ag_series.svg')
plt.draw()
# Out:
# (36000,)

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)


treatment='D1Ant'
ID_n=3
time_point=50

strt=15
fini=50
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D1A_series.svg')
plt.draw()
# Out:
# (17024,)

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)


treatment='D2Ant'
ID_n=3
time_point=50

strt=15
fini=50
cut=3000
fps=50

fig, ax = plt.subplots(4)
ax=visual_config.visualize_ts(ax, dct,  ID_n, time_point,strt, fini, ts, model, cut, fps, treatment)

#plt.tight_layout()
plt.savefig('D2A_series.svg')
plt.draw()
# Out:
# (17012,)

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


animal_ID=4
time_point=30
lower_cut=0
upper_cut=3000
fps=50

treatment='LD-3mg'

head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarLID.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


animal_ID=4
time_point=30
lower_cut=0
upper_cut=3000
fps=50

treatment='LD-3mg'

head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarLID.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)



animal_ID=1
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ag'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarSUM.svg', dpi=360)
plt.draw()
# Out:
# (3600,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)


animal_ID=0
time_point=70
lower_cut=500
upper_cut=2500
fps=50

treatment='D1Ag'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)#+(np.pi/2)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )

plt.savefig('polarSKF.svg', dpi=360)
plt.draw()
# Out:
# (7200,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)

animal_ID=2
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D1Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD1A.svg', dpi=360)
plt.draw()
# Out:
# (17023,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)


animal_ID=2
time_point=30
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD2A.svg', dpi=360)
plt.draw()
# Out:
# (16930,)
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:196: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['270', '', '0', '', '90', '', '180', ''])

# %%
evalu=['LES']
dct=data_base.get_dct(evalu)


animal_ID=0
time_point=71
lower_cut=500
upper_cut=2500
fps=50

treatment='D2Ant'
#print(dct[list(dct.keys())][ID_n])
head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)

head_orientation=(head_ang/57.32)
time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax=visual_config.head_polar_plot(ax, head_orientation, ar,lower_cut, upper_cut, treatment,
                     alph=0.05 )


plt.savefig('polarD2A_les.svg', dpi=360)
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\dlc_projects\Analysis\git_repo\Figures\open_field_visalization.ipynb Cell 14 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> treatment='D2Ant'
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> #print(dct[list(dct.keys())][ID_n])
# ---> <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> head_ang, ar, rot_speed, translate=ts.time_srs(dct, animal_ID, time_point)
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> head_orientation=(head_ang/57.32)
#      <a href='vscode-notebook-cell:/c%3A/dlc_projects/Analysis/git_repo/Figures/open_field_visalization.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> time=np.linspace(0,upper_cut-lower_cut, upper_cut-lower_cut)/fps
#
# File c:\dlc_projects\Analysis\git_repo\util\single_ts.py:62, in dlc_ts.time_srs(self, dct, ID_n, t_p)
#      58 def time_srs(self, dct, ID_n:'the animal idx', t_p:'the time point') -> 'thet_head, ar, rot_speed, translate':
#      60     ky=list(dct.keys())[ID_n]                #select the animal
# ---> 62     self.ar0=dct[ky]['ar0']
#      64     dlc_dct=dct[ky]['traces'][str(t_p)]     #get the x,y data set
#      65     treatment=dct[ky]['treatment']
#
# KeyError: 'ar0'

# %%
evalu=['LID']
dct=data_base.get_dct(evalu)


time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )

plt.savefig('openLID.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['SUM']
dct=data_base.get_dct(evalu)

time_point=30
animal_ID=0
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openSUM.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['SKF']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openSKF.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['D1A']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2  
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD1A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['D2A']
dct=data_base.get_dct(evalu)

time_point=40
animal_ID=2
time_point=30
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD2A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,

# %%
evalu=['LES']
dct=data_base.get_dct(evalu)

time_point=70
animal_ID=0
lower_cut=100
upper_cut=7500
fps=50


cent_x,cent_y=ts.get_centroid(dct, animal_ID,time_point)
fig, ax = plt.subplots()
ax=visual_config.presence_heat_maps(ax,cent_x,cent_y, lower_cut, upper_cut )


plt.savefig('openD1A.svg', dpi=360)
plt.draw()
# Out:
# c:\dlc_projects\Analysis\git_repo\util\visualization_config.py:226: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cent_x[lower_cut:upper_cut],y=cent_y[lower_cut:upper_cut],shade=True,
